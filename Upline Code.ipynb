# %%
import pandas as pd

# %%
import pandas as pd

# Read files
main = pd.read_excel(r"C:\Users\new\Downloads\SDC 23 Nov.xlsx")
a1175 = pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\1175.xlsx")
a9718 = pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\9718.xlsx")
a18235 = pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\18235.xlsx")
a791313= pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\791313.xlsx")
a950081= pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\950081.xlsx")
a2520=   pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\2520.xlsx")
a6689=   pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\6689.xlsx")
a65077=  pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\65077.xlsx")
a1786=   pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\1786.xlsx")
a1155=   pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\1155.xlsx")
a301238= pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\301238.xlsx")
a43756=  pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\43756.xlsx")
a1151=   pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\1151.xlsx")
a4934=   pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\4934.xlsx")
a4922=   pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\4922.xlsx")
a6955=   pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\6955.xlsx")
# a48368 = pd.read_excel(r"C:\Users\new\Desktop\upline 9 oct\48368.xlsx")
a2840=   pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\2840.xlsx")
a2669=   pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\2669.xlsx")
a29433=  pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\29433.xlsx")
a87846=  pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\87846.xlsx")
a35450=  pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\35450.xlsx")
a3015 = pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\3015.xlsx")
a3483702 = pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\3483702.xlsx")
a24563 = pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\24563.xlsx")
a1188 = pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\1188.xlsx")
a2813470 = pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\2813470.xlsx")
a1472 = pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\1472.xlsx")
a7191626 = pd.read_excel(r"C:\Users\new\Desktop\Upline 8 Dec\7191626.xlsx")
# Strip whitespace from IDs (important for matching)
main['User Id'] = main['User Id'].astype(str).str.strip()
a1175['User Id'] = a1175['Associate ID'].astype(str).str.strip()
a9718['User Id'] = a9718['Associate ID'].astype(str).str.strip()
a18235['User Id'] = a18235['Associate ID'].astype(str).str.strip()
a791313['User Id'] = a791313['Associate ID'].astype(str).str.strip()
a950081['User Id'] = a950081['Associate ID'].astype(str).str.strip()
a2520['User Id'] = a2520['Associate ID'].astype(str).str.strip()
a6689['User Id'] = a6689['Associate ID'].astype(str).str.strip()
a65077['User Id'] = a65077['Associate ID'].astype(str).str.strip()
a1786['User Id'] = a1786['Associate ID'].astype(str).str.strip()
a1155['User Id'] = a1155['Associate ID'].astype(str).str.strip()
a301238['User Id'] = a301238['Associate ID'].astype(str).str.strip()
a43756['User Id'] = a43756['Associate ID'].astype(str).str.strip()
a1151['User Id'] = a1151['Associate ID'].astype(str).str.strip()
a4934['User Id'] = a4934['Associate ID'].astype(str).str.strip()
a4922['User Id'] = a4922['Associate ID'].astype(str).str.strip()
a6955['User Id'] = a6955['Associate ID'].astype(str).str.strip()
# a48368['User Id'] = a48368['Associate ID'].astype(str).str.strip()
a2840['User Id'] = a2840['Associate ID'].astype(str).str.strip()
a2669['User Id'] = a2669['Associate ID'].astype(str).str.strip()
a29433['User Id'] = a29433['Associate ID'].astype(str).str.strip()
a87846['User Id'] = a87846['Associate ID'].astype(str).str.strip()
a35450['User Id'] = a35450['Associate ID'].astype(str).str.strip()
a3015['User Id'] = a3015['Associate ID'].astype(str).str.strip()
a3483702['User Id'] = a3483702['Associate ID'].astype(str).str.strip()
a24563['User Id'] = a24563['Associate ID'].astype(str).str.strip()
a1188['User Id'] = a1188['Associate ID'].astype(str).str.strip()
a2813470['User Id'] = a2813470['Associate ID'].astype(str).str.strip()
a1472['User Id'] = a1472['Associate ID'].astype(str).str.strip()
a7191626['User Id'] = a7191626['Associate ID'].astype(str).str.strip()


# Create new column
main["UPLINE"] = ""

# Mark IDs belonging to Mukesh Singh
main.loc[main['User Id'].isin(a1175['Associate ID']), "UPLINE"] = "MUKESH SINGH"
main.loc[main['User Id'].isin(a9718['Associate ID']), "UPLINE"] = "R.K. Mishra"
main.loc[main['User Id'].isin(a18235['Associate ID']), "UPLINE"] = "SUKANTA JENA"
main.loc[main['User Id'].isin(a791313['Associate ID']), "UPLINE"] = "SURESH PARIDA"
main.loc[main['User Id'].isin(a950081['Associate ID']), "UPLINE"] = "RANJITA PANDA"
main.loc[main['User Id'].isin(a2520['Associate ID']), "UPLINE"] = "SARWAN KUMAR"
main.loc[main['User Id'].isin(a6689['Associate ID']), "UPLINE"] = "SURENDER KUMAR YADAV"
main.loc[main['User Id'].isin(a65077['Associate ID']), "UPLINE"] = "SHAILASH KUMAR"
main.loc[main['User Id'].isin(a1786['Associate ID']), "UPLINE"] = "ALTAF HUSAIN ANSARI"
main.loc[main['User Id'].isin(a1155['Associate ID']), "UPLINE"] = "RANA PRATAP SINGH"
main.loc[main['User Id'].isin(a301238['Associate ID']), "UPLINE"] = "SHIVBACHAN CHAUHAN"
main.loc[main['User Id'].isin(a43756['Associate ID']), "UPLINE"] = "RAM CHANDRA"
main.loc[main['User Id'].isin(a1151['Associate ID']), "UPLINE"] = "RAJESH KUMAR DIXIT"
main.loc[main['User Id'].isin(a4934['Associate ID']), "UPLINE"] = "RADHESHYAM RAM"
main.loc[main['User Id'].isin(a4922['Associate ID']), "UPLINE"] = "ABID ALI"
main.loc[main['User Id'].isin(a6955['Associate ID']), "UPLINE"] = "AMIR ANSARI"
# main.loc[main['User Id'].isin(a48368['Associate ID']), "UPLINE"] = "MD MERAZ"
main.loc[main['User Id'].isin(a2840['Associate ID']), "UPLINE"] = "NARESH KUMAR"
main.loc[main['User Id'].isin(a2669['Associate ID']), "UPLINE"] = "KARAMVIR"
main.loc[main['User Id'].isin(a29433['Associate ID']), "UPLINE"] = "RAMESH KUMAR"
main.loc[main['User Id'].isin(a87846['Associate ID']), "UPLINE"] = "GAYANAND SHARMA"
main.loc[main['User Id'].isin(a35450['Associate ID']), "UPLINE"] = "MUKESH SAGAR"
main.loc[main['User Id'].isin(a3015['Associate ID']), "UPLINE"] = "DHARAMVIR"
main.loc[main['User Id'].isin(a3483702['Associate ID']), "UPLINE"] = "Shailender kumar"
main.loc[main['User Id'].isin(a24563['Associate ID']), "UPLINE"] = "SARVESH BAHADUR SINGH"
main.loc[main['User Id'].isin(a1188['Associate ID']), "UPLINE"] = "HULAS DAS SAHU"
main.loc[main['User Id'].isin(a2813470['Associate ID']), "UPLINE"] = "ABBAS A MIRZA"
main.loc[main['User Id'].isin(a1472['Associate ID']), "UPLINE"] = "SATPAL G"
main.loc[main['User Id'].isin(a7191626['Associate ID']), "UPLINE"] = "ISHWAR PRASAD SAHU"
# Save updated file
main.to_excel(r"C:\Users\new\Downloads\SDC 23 Nov.xlsx", index=False)

# %%
print("hello")
# Out:
# hello
